# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Неполное среднее', 'Среднее специальное', 'Среднее', 'Неоконченное высшее', 'Два и более высших образования', 'Ученая степень', 'Высшее'}
#
#
# ==========
# MARITAL_STATUS
# {'Состою в браке', 'Гражданский брак', 'Вдовец/Вдова', 'Разведен(а)', 'Не состоял в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {'Образование', nan, 'Другие сферы', 'Наука', 'Коммунальное хоз-во/Дорожные службы', 'Химия/Парфюмерия/Фармацевтика', 'Недвижимость', 'Развлечения/Искусство', 'Строительство', 'Здравоохранение', 'СМИ/Реклама/PR-агенства', 'Сборочные производства', 'Транспорт', 'Страхование', 'ЧОП/Детективная д-ть', 'Туризм', 'Логистика', 'Сельское хозяйство', 'Государственная служба', 'Банк/Финансы', 'Металлургия/Промышленность/Машиностроение', 'Торговля', 'Нефтегазовая промышленность', 'Ресторанный бизнес/Общественное питание', 'Информационные технологии', 'Юридические услуги/нотариальные услуги', 'Информационные услуги', 'Маркетинг', 'Салоны красоты и здоровья', 'Энергетика', 'Подбор персонала', 'Управляющая компания'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Военнослужащий по контракту', 'Партнер', 'Высококвалифиц. специалист', 'Руководитель низшего звена', 'Другое', 'Руководитель среднего звена', 'Работник сферы услуг', 'Индивидуальный предприниматель', 'Рабочий', 'Руководитель высшего звена', 'Специалист', 'Служащий'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Государственная комп./учреж.', 'Некоммерческая организация', 'Индивидуальный предприниматель', 'Частная ком. с инос. капиталом', 'Частная компания'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {'Без участия', nan, 'С участием'}
#
#
# ==========
# JOB_DIR
# {'Участие в основ. деятельности', 'Служба безопасности', nan, 'Юридическая служба', 'Бухгалтерия, финансы, планир.', 'Вспомогательный техперсонал', 'Снабжение и сбыт', 'Кадровая служба и секретариат', 'Адм-хоз. и трансп. службы', 'Реклама и маркетинг', 'Пр-техн. обесп. и телеком.'}
#
#
# ==========
# FAMILY_INCOME
# {'от 5000 до 10000 руб.', 'от 10000 до 20000 руб.', 'от 20000 до 50000 руб.', 'до 5000 руб.', 'свыше 50000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'10600', '5100', '12100', '8000', '8800', '19000', '18500', '16500', '6100', '4330', '41000', '65000', '13200', '39000', '27000', '13800', '5582', '26000', '48000', '17000', '21000', '12500', '7500', '11500', '4700', '42500', '3000', '9500', '10900', '17700', '7220', '17800', '14300', '13300', '41900', '5088', '5300', '17404', '3300', '19700', '75000', '20000', '6700', '37000', '14000', '24', '34000', '4950', '8250', '10100', '8400', '70000', '13450', '4515', '52000', '12650', '40000', '10500', '9600', '8700', '9100', '4100', '1950', '56000', '110000', '7101', '4000', '33000', '4600', '15380', '5800', '5680', '15560', '35000', '6670', '6800', '12900', '11640', '3600', '5339', '2100', '16100', '12600', '5200', '23100', '80000', '21800', '22000', '9300', '9800', '16000', '28300', '29800', '100000', '53000', '22500', '12300', '6180', '32640', '92000', '7900', '43000', '250000', '67700', '5360', '170000', '4400', '6400', '7550', '23800', '9240', '8350', '5900', '4340', '7100', '3400', '5400', '7250', '8300', '8500', '5000', '4590', '47000', '44000', '5050', '8200', '29500', '77000', '16800', '6608', '22955', '8900', '24800', '10000', '7600', '3800', '12400', '9400', '6900', '3700', '13160', '4800', '17200', '4500', '17900', '25000', '5446', '29000', '18600', '11900', '55000', '20646,16', '12800', '5500', '7200', '10200', '17600', '5460', '2000', '42000', '32000', '21500', '26500', '3900', '11000', '150000', '11200', '14700', '6300', '9700', '6500', '5425', '27300', '5700', '11700', '19300', '17500', '7050', '23000', '68000', '9330', '5230', '9628', '51000', '16050', '7640', '10800', '54000', '67000', '7650', '6359', '18200', '11800', '15400', '14500', '19600', '7700', '6200', '4900', '9340', '4200', '7251', '18700', '45000', '36000', '15300', '7800', '13700', '2800', '16700', '49000', '16900', '9000', '31000', '10300', '11400', '19800', '7400', '4360', '13150', '7000', '15600', '7830', '3100', '3500', '7300', '38000', '15000', '15500', '14800', '9900', '13600', '5600', '13400', '220000', '5350', '9200', '16200', '18000', '28000', '4300', '60000', '13900', '20500', '11300', '8726', '8600', '13000', '160000', '6600', '3200', '24500', '23500', '6000', '11600', '10700', '8100', '2300', '10400', '15200', '12000', '8066', '12700', '7850', '25800', '50000', '6299,19', '46000', '14358', '24000', '13500', '30000', '5790', '19500'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Дагестан', 'Кировская область', 'Башкирия', 'Ярославская область', 'Новгородская область', 'Якутия', 'Курская область', 'Мордовская республика', 'Калининградская область', 'Тверская область', 'Пермская область', 'Сахалинская область', 'Тамбовская область', 'Костромская область', 'Курганская область', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Кабардино-Балкария', 'Москва', 'Новосибирская область', 'Ставропольский край', 'Архангельская область', 'Горный Алтай', 'Смоленская область', 'Астраханская область', 'Липецкая область', 'Хабаровский край', 'Еврейская АО', 'Красноярский край', 'Оренбургская область', 'Чувашия', 'Коми', 'Бурятия', 'Эвенкийский АО', 'Ямало-Ненецкий АО', 'Татарстан', 'Приморский край', 'Саратовская область', 'Ростовская область', 'Ленинградская область', 'Челябинская область', 'Омская область', 'Псковская область', 'Амурская область', 'Ханты-Мансийский АО', 'Читинская область', 'Воронежская область', 'Вологодская область', 'Кемеровская область', 'Камчатская область', 'Санкт-Петербург', 'Нижегородская область', 'Тульская область', 'Ульяновская область', 'Томская область', 'Карачаево-Черкесия', 'Пензенская область', 'Иркутская область', 'Московская область', 'Алтайский край', 'Усть-Ордынский Бурятский АО', 'Рязанская область', 'Волгоградская область', 'Калужская область', 'Агинский Бурятский АО', 'Карелия', 'Белгородская область', 'Самарская область', 'Ивановская область', 'Краснодарский край', 'Марийская республика', 'Северная Осетия', 'Владимирская область', 'Орловская область', 'Адыгея', 'Тюменская область', 'Мурманская область', 'Брянская область', 'Хакасия', 'Магаданская область'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Дагестан', 'Кировская область', 'Башкирия', 'Ярославская область', 'Новгородская область', 'Якутия', 'Курская область', 'Мордовская республика', 'Калининградская область', 'Тверская область', 'Пермская область', 'Сахалинская область', 'Тамбовская область', 'Костромская область', 'Курганская область', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Кабардино-Балкария', 'Москва', 'Новосибирская область', 'Ставропольский край', 'Архангельская область', 'Горный Алтай', 'Смоленская область', 'Астраханская область', 'Липецкая область', 'Хабаровский край', 'Еврейская АО', 'Красноярский край', 'Оренбургская область', 'Чувашия', 'Коми', 'Бурятия', 'Эвенкийский АО', 'Ямало-Ненецкий АО', 'Татарстан', 'Приморский край', 'Саратовская область', 'Ростовская область', 'Ленинградская область', 'Челябинская область', 'Омская область', 'Псковская область', 'Амурская область', 'Ханты-Мансийский АО', 'Читинская область', 'Воронежская область', 'Вологодская область', 'Кемеровская область', 'Камчатская область', 'Санкт-Петербург', 'Нижегородская область', 'Тульская область', 'Ульяновская область', 'Томская область', 'Карачаево-Черкесия', 'Московская область', 'Иркутская область', 'Пензенская область', 'Алтайский край', 'Усть-Ордынский Бурятский АО', 'Рязанская область', 'Волгоградская область', 'Калужская область', 'Агинский Бурятский АО', 'Карелия', 'Белгородская область', 'Самарская область', 'Ивановская область', 'Краснодарский край', 'Марийская республика', 'Северная Осетия', 'Владимирская область', 'Орловская область', 'Адыгея', 'Тюменская область', 'Мурманская область', 'Брянская область', 'Хакасия', 'Магаданская область'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Кировская область', 'Башкирия', 'Ярославская область', 'Новгородская область', 'Якутия', 'Курская область', 'Мордовская республика', 'Калининградская область', 'Тверская область', 'Пермская область', 'Сахалинская область', 'Тамбовская область', 'Костромская область', 'Курганская область', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Кабардино-Балкария', 'Москва', 'Новосибирская область', 'Ставропольский край', 'Архангельская область', 'Горный Алтай', 'Смоленская область', 'Астраханская область', 'Липецкая область', 'Хабаровский край', 'Еврейская АО', 'Красноярский край', 'Оренбургская область', 'Чувашия', 'Коми', 'Бурятия', 'Эвенкийский АО', 'Ямало-Ненецкий АО', 'Татарстан', 'Приморский край', 'Саратовская область', 'Ростовская область', 'Ленинградская область', 'Челябинская область', 'Омская область', 'Псковская область', 'Амурская область', 'Ханты-Мансийский АО', 'Читинская область', 'Воронежская область', 'Вологодская область', 'Кемеровская область', 'Камчатская область', 'Санкт-Петербург', 'Нижегородская область', 'Тульская область', 'Ульяновская область', 'Томская область', 'Карачаево-Черкесия', 'Московская область', 'Иркутская область', 'Пензенская область', 'Алтайский край', 'Усть-Ордынский Бурятский АО', 'Рязанская область', 'Волгоградская область', 'Калужская область', 'Агинский Бурятский АО', 'Карелия', 'Белгородская область', 'Самарская область', 'Ивановская область', 'Краснодарский край', 'Марийская республика', 'Северная Осетия', 'Владимирская область', 'Орловская область', 'Адыгея', 'Тюменская область', 'Мурманская область', 'Брянская область', 'Хакасия', 'Магаданская область'}
#
#
# ==========
# TP_PROVINCE
# {nan, 'Кировская область', 'Башкирия', 'Ярославская область', 'Новгородская область', 'Якутия', 'Курская область', 'Мордовская республика', 'Калининградская область', 'Тверская область', 'Пермская область', 'Сахалинская область', 'Тамбовская область', 'Костромская область', 'Курганская область', 'Свердловская область', 'Удмуртия', 'Москва', 'Кабардино-Балкария', 'Ставропольский край', 'Новосибирская область', 'Архангельская область', 'Горный Алтай', 'Смоленская область', 'Астраханская область', 'Липецкая область', 'Хабаровский край', 'Еврейская АО', 'Красноярский край', 'Оренбургская область', 'Чувашия', 'Коми', 'Бурятия', 'Татарстан', 'Приморский край', 'Саратовская область', 'Ростовская область', 'Челябинская область', 'Омская область', 'Псковская область', 'Амурская область', 'Ханты-Мансийский АО', 'Читинская область', 'Воронежская область', 'Вологодская область', 'Санкт-Петербург', 'Камчатская область', 'Кемеровская область', 'Нижегородская область', 'Тульская область', 'Ульяновская область', 'Томская область', 'Пензенская область', 'Иркутская область', 'Алтайский край', 'Рязанская область', 'Волгоградская область', 'Калужская область', 'Карелия', 'Белгородская область', 'Самарская область', 'Ивановская область', 'Краснодарский край', 'Марийская республика', 'Владимирская область', 'Орловская область', 'Адыгея', 'Тюменская область', 'Мурманская область', 'Брянская область', 'Магаданская область'}
#
#
# ==========
# REGION_NM
# {'ЮЖНЫЙ', nan, 'ЦЕНТРАЛЬНЫЙ 1', 'УРАЛЬСКИЙ', 'ПОВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ПРИВОЛЖСКИЙ', 'ВОСТОЧНО-СИБИРСКИЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'СЕВЕРО-
...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %%
df.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59909969       0   30                  1                  0       1
# 1      59910420       0   48                  0                  1       1
# 2      59911223       0   35                  1                  0       0
# 3      59911322       0   22                  1                  0       0
# 4      59911438       0   27                  1                  0       1
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION      MARITAL_STATUS  ...    \
# 0            1           1  Среднее специальное  Не состоял в браке  ...
# 1            0           0              Среднее      Состою в браке  ...
# 2            1           0              Среднее  Не состоял в браке  ...
# 3            0           0              Среднее  Не состоял в браке  ...
# 4            2           2               Высшее      Состою в браке  ...
#
#   GEN_PHONE_FL LOAN_NUM_TOTAL LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM  \
# 0            1              2               2             8            0
# 1            0              2               1            15            0
# 2            1              1               1             1            0
# 3            1              3               2             9            0
# 4            1              1               1             5            0
#
#   LOAN_MAX_DLQ LOAN_AVG_DLQ_AMT LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED  \
# 0            0                0                0                        NaN
# 1            0                0                0                        NaN
# 2            0                0                0                        NaN
# 3            0                0                0                        NaN
# 4            0                0                0                        NaN
#
#   sample
# 0   test
# 1   test
# 2   test
# 3   test
# 4   test
#
# [5 rows x 53 columns]

# %%
df.isnull().sum()
# Out:
# AGREEMENT_RK                      0
# TARGET                            0
# AGE                               0
# SOCSTATUS_WORK_FL                 0
# SOCSTATUS_PENS_FL                 0
# GENDER                            0
# CHILD_TOTAL                       0
# DEPENDANTS                        0
# EDUCATION                         0
# MARITAL_STATUS                    0
# GEN_INDUSTRY                   2713
# GEN_TITLE                      2713
# ORG_TP_STATE                   2713
# ORG_TP_FCAPITAL                2708
# JOB_DIR                        2713
# FAMILY_INCOME                     0
# PERSONAL_INCOME                   0
# REG_ADDRESS_PROVINCE              0
# FACT_ADDRESS_PROVINCE             0
# POSTAL_ADDRESS_PROVINCE           0
# TP_PROVINCE                     590
# REGION_NM                         2
# REG_FACT_FL                       0
# FACT_POST_FL                      0
# REG_POST_FL                       0
# REG_FACT_POST_FL                  0
# REG_FACT_POST_TP_FL               0
# FL_PRESENCE_FL                    0
# OWN_AUTO                          0
# AUTO_RUS_FL                       0
# HS_PRESENCE_FL                    0
# COT_PRESENCE_FL                   0
# GAR_PRESENCE_FL                   0
# LAND_PRESENCE_FL                  0
# CREDIT                            0
# TERM                              0
# FST_PAYMENT                       0
# DL_DOCUMENT_FL                    0
# GPF_DOCUMENT_FL                   0
# FACT_LIVING_TERM                  0
# WORK_TIME                      2717
# FACT_PHONE_FL                     0
# REG_PHONE_FL                      0
# GEN_PHONE_FL                      0
# LOAN_NUM_TOTAL                    0
# LOAN_NUM_CLOSED                   0
# LOAN_NUM_PAYM                     0
# LOAN_DLQ_NUM                      0
# LOAN_MAX_DLQ                      0
# LOAN_AVG_DLQ_AMT                  0
# LOAN_MAX_DLQ_AMT                  0
# PREVIOUS_CARD_NUM_UTILIZED    29533
# sample                            0
# dtype: int64

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
#df.head()

#df["AGE"].mean()

#df.isnull().sum()

#df['GEN_INDUSTRY'] = df['GEN_INDUSTRY'].fillna(1)

#df.isnull().sum()

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

print('\n')
print('=== GEN_INDUSTRY ====================================================')

label_encoder = LabelEncoder()
pd.Series(label_encoder.fit_transform(df['GEN_INDUSTRY'].astype('str')))
print(dict(enumerate(label_encoder.classes_)))

print('\n')
print('=== GEN_TITLE =======================================================')

label_encoder = LabelEncoder()
pd.Series(label_encoder.fit_transform(df['GEN_TITLE'].astype('str')))
print(dict(enumerate(label_encoder.classes_)))

print('\n')
print('=== ORG_TP_STATE ====================================================')

label_encoder = LabelEncoder()
pd.Series(label_encoder.fit_transform(df['ORG_TP_STATE'].astype('str')))
print(dict(enumerate(label_encoder.classes_)))

print('\n')
print('=== ORG_TP_FCAPITAL =================================================')

label_encoder = LabelEncoder()
pd.Series(label_encoder.fit_transform(df['ORG_TP_FCAPITAL'].astype('str')))
print(dict(enumerate(label_encoder.classes_)))

print('\n')
print('=== JOB_DIR =========================================================')

label_encoder = LabelEncoder()
pd.Series(label_encoder.fit_transform(df['JOB_DIR'].astype('str')))
print(dict(enumerate(label_encoder.classes_)))

print('\n')
print('=== TP_PROVINCE =====================================================')

label_encoder = LabelEncoder()
pd.Series(label_encoder.fit_transform(df['TP_PROVINCE'].astype('str')))
print(dict(enumerate(label_encoder.classes_)))
# Out:
# === GEN_INDUSTRY ====================================================
# {0: 'nan', 1: 'Банк/Финансы', 2: 'Государственная служба', 3: 'Другие сферы', 4: 'Здравоохранение', 5: 'Информационные технологии', 6: 'Информационные услуги', 7: 'Коммунальное хоз-во/Дорожные службы', 8: 'Логистика', 9: 'Маркетинг', 10: 'Металлургия/Промышленность/Машиностроение', 11: 'Наука', 12: 'Недвижимость', 13: 'Нефтегазовая промышленность', 14: 'Образование', 15: 'Подбор персонала', 16: 'Развлечения/Искусство', 17: 'Ресторанный бизнес/Общественное питание', 18: 'СМИ/Реклама/PR-агенства', 19: 'Салоны красоты и здоровья', 20: 'Сборочные производства', 21: 'Сельское хозяйство', 22: 'Страхование', 23: 'Строительство', 24: 'Торговля', 25: 'Транспорт', 26: 'Туризм', 27: 'Управляющая компания', 28: 'Химия/Парфюмерия/Фармацевтика', 29: 'ЧОП/Детективная д-ть', 30: 'Энергетика', 31: 'Юридические услуги/нотариальные услуги'}
#
#
# === GEN_TITLE =======================================================
# {0: 'nan', 1: 'Военнослужащий по контракту', 2: 'Высококвалифиц. специалист', 3: 'Другое', 4: 'Индивидуальный предприниматель', 5: 'Партнер', 6: 'Работник сферы услуг', 7: 'Рабочий', 8: 'Руководитель высшего звена', 9: 'Руководитель низшего звена', 10: 'Руководитель среднего звена', 11: 'Служащий', 12: 'Специалист'}
#
#
# === ORG_TP_STATE ====================================================
# {0: 'nan', 1: 'Государственная комп./учреж.', 2: 'Индивидуальный предприниматель', 3: 'Некоммерческая организация', 4: 'Частная ком. с инос. капиталом', 5: 'Частная компания'}
#
#
# === ORG_TP_FCAPITAL =================================================
# {0: 'nan', 1: 'Без участия', 2: 'С участием'}
#
#
# === JOB_DIR =========================================================
# {0: 'nan', 1: 'Адм-хоз. и трансп. службы', 2: 'Бухгалтерия, финансы, планир.', 3: 'Вспомогательный техперсонал', 4: 'Кадровая служба и секретариат', 5: 'Пр-техн. обесп. и телеком.', 6: 'Реклама и маркетинг', 7: 'Служба безопасности', 8: 'Снабжение и сбыт', 9: 'Участие в основ. деятельности', 10: 'Юридическая служба'}
#
#
# === TP_PROVINCE =====================================================
# {0: 'nan', 1: 'Адыгея', 2: 'Алтайский край', 3: 'Амурская область', 4: 'Архангельская область', 5: 'Астраханская область', 6: 'Башкирия', 7: 'Белгородская область', 8: 'Брянская область', 9: 'Бурятия', 10: 'Владимирская область', 11: 'Волгоградская область', 12: 'Вологодская область', 13: 'Воронежская область', 14: 'Горный Алтай', 15: 'Еврейская АО', 16: 'Ивановская область', 17: 'Иркутская область', 18: 'Кабардино-Балкария', 19: 'Калининградская область', 20: 'Калужская область', 21: 'Камчатская область', 22: 'Карелия', 23: 'Кемеровская область', 24: 'Кировская область', 25: 'Коми', 26: 'Костромская область', 27: 'Краснодарский край', 28: 'Красноярский край', 29: 'Курганская область', 30: 'Курская область', 31: 'Липецкая область', 32: 'Магаданская область', 33: 'Марийская республика', 34: 'Мордовская республика', 35: 'Москва', 36: 'Мурманская область', 37: 'Нижегородская область', 38: 'Новгородская область', 39: 'Новосибирская область', 40: 'Омская область', 41: 'Оренбургская область', 42: 'Орловская область', 43: 'Пензенская область', 44: 'Пермская область', 45: 'Приморский край', 46: 'Псковская область', 47: 'Ростовская область', 48: 'Рязанская область', 49: 'Самарская область', 50: 'Санкт-Петербург', 51: 'Саратовская область', 52: 'Сахалинская область', 53: 'Свердловская область', 54: 'Смоленская область', 55: 'Ставропольский край', 56: 'Тамбовская область', 57: 'Татарстан', 58: 'Тверская область', 59: 'Томская область', 60: 'Тульская область', 61: 'Тюменская область', 62: 'Удмуртия', 63: 'Ульяновская область', 64: 'Хабаровский край', 65: 'Ханты-Мансийский АО', 66: 'Челябинская область', 67: 'Читинская область', 68: 'Чувашия', 69: 'Якутия', 70: 'Ярославская область'}

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

def preproc_data(df_input):
    df_output = df_input.drop(['AGREEMENT_RK', 'PREVIOUS_CARD_NUM_UTILIZED'], axis=1)

    for column in ['PERSONAL_INCOME', 'CREDIT', 'FST_PAYMENT', 'LOAN_AVG_DLQ_AMT', 'LOAN_MAX_DLQ_AMT']:
        df_output[column].map(lambda x: x.replace(',', '.')).astype('float')

    categorical_columns = df_output.columns[df_output.dtypes == 'object']
    
    for column in categorical_columns:
        df_output[column] = label_encoder.fit_transform(df_output[column].astype('str'))
        
    

    return df_output

# %%
df_preproc = df.pipe(preproc_data)

#df_preproc.head()

df_preproc.isnull().sum()

#df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
#df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)
# Out:
# TARGET                        0
# AGE                           0
# SOCSTATUS_WORK_FL             0
# SOCSTATUS_PENS_FL             0
# GENDER                        0
# CHILD_TOTAL                   0
# DEPENDANTS                    0
# EDUCATION                     0
# MARITAL_STATUS                0
# GEN_INDUSTRY                  0
# GEN_TITLE                     0
# ORG_TP_STATE                  0
# ORG_TP_FCAPITAL               0
# JOB_DIR                       0
# FAMILY_INCOME                 0
# PERSONAL_INCOME               0
# REG_ADDRESS_PROVINCE          0
# FACT_ADDRESS_PROVINCE         0
# POSTAL_ADDRESS_PROVINCE       0
# TP_PROVINCE                   0
# REGION_NM                     0
# REG_FACT_FL                   0
# FACT_POST_FL                  0
# REG_POST_FL                   0
# REG_FACT_POST_FL              0
# REG_FACT_POST_TP_FL           0
# FL_PRESENCE_FL                0
# OWN_AUTO                      0
# AUTO_RUS_FL                   0
# HS_PRESENCE_FL                0
# COT_PRESENCE_FL               0
# GAR_PRESENCE_FL               0
# LAND_PRESENCE_FL              0
# CREDIT                        0
# TERM                          0
# FST_PAYMENT                   0
# DL_DOCUMENT_FL                0
# GPF_DOCUMENT_FL               0
# FACT_LIVING_TERM              0
# WORK_TIME                  2717
# FACT_PHONE_FL                 0
# REG_PHONE_FL                  0
# GEN_PHONE_FL                  0
# LOAN_NUM_TOTAL                0
# LOAN_NUM_CLOSED               0
# LOAN_NUM_PAYM                 0
# LOAN_DLQ_NUM                  0
# LOAN_MAX_DLQ                  0
# LOAN_AVG_DLQ_AMT              0
# LOAN_MAX_DLQ_AMT              0
# sample                        0
# dtype: int64

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

## Your Code Here
# Out:
# /home/vasily/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

## Your Code Here

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

## Your Code Here

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

## Your Code Here

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

## Your Code Here

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here

# %%
# Померить roc_auc на тесте
